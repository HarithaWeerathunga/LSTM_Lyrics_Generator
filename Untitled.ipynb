# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, LSTM, Dense, Bidirectional
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data.txt', sep="\n ", on_bad_lines='skip', header=None)
# Out:
# C:\Users\Haritha Weerathunga\AppData\Local\Temp\ipykernel_13856\746365583.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv('data.txt', sep="\n ", on_bad_lines='skip', header=None)

# %%
data
# Out:
#                                                       0
# 0     Look, I was gonna go easy on you and not to hu...
# 1             But I'm only going to get this one chance
# 2     Something's wrong, I can feel it (Six minutes,...
# 3     Just a feeling I've got, like something's abou...
# 4     If that means, what I think it means, we're in...
# ...                                                 ...
# 6807  You hear me? Answer me! Bitch I'm a kill you! ...
# 6808    Girls leave, you ain't nothin' but a slut to me
# 6809  Bitch I'm a kill you! You ain't got the balls ...
# 6810  We ain't goin' never stop beefin' I don't squa...
# 6811                               You know, I love you
#
# [6812 rows x 1 columns]

# %%
corpus = list(set(data[0]))

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)

# %%
total_words = len(tokenizer.word_index) + 1

# %%
total_words
# Out:
# 6115

# %%
print(tokenizer.word_index)
# Out:
# {'i': 1, 'the': 2, 'you': 3, 'to': 4, 'and': 5, 'a': 6, "i'm": 7, 'my': 8, 'it': 9, 'me': 10, 'in': 11, 'that': 12, 'this': 13, 'of': 14, 'like': 15, 'but': 16, 'just': 17, 'on': 18, 'so': 19, 'your': 20, "don't": 21, 'is': 22, 'with': 23, 'get': 24, 'up': 25, 'for': 26, 'be': 27, "it's": 28, 'no': 29, 'what': 30, 'all': 31, 'know': 32, 'now': 33, 'when': 34, 'was': 35, 'fuck': 36, 'out': 37, "ain't": 38, 'they': 39, 'got': 40, 'shit': 41, 'can': 42, 'we': 43, 'back': 44, 'if': 45, 'at': 46, 'go': 47, 'he': 48, 'not': 49, 'from': 50, 'as': 51, "'cause": 52, 'do': 53, 'one': 54, 'off': 55, 'see': 56, 'his': 57, 'say': 58, 'think': 59, 'her': 60, 'bitch': 61, 'make': 62, 'have': 63, "you're": 64, 'never': 65, 'down': 66, 'then': 67, 'ass': 68, 'or': 69, 'way': 70, 'take': 71, 'these': 72, "that's": 73, "i'll": 74, 'oh': 75, 'who': 76, 'right': 77, 'how': 78, 'too': 79, 'him': 80, "'em": 81, 'why': 82, 'want': 83, 'even': 84, "can't": 85, 'let': 86, 'love': 87, 'are': 88, 'feel': 89, 't
# ...

# %%
input_word_sequences = []

# %%
for line in corpus:
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(token_list)):
        n_gram_sequence = token_list[: i+1]
        input_word_sequences.append(n_gram_sequence)

# %%
#input_word_sequences

# %%
max_sequence_len = max([len(x) for x in input_word_sequences])

# %%
max_sequence_len
# Out:
# 33

# %%
input_sequences = np.array(pad_sequences(input_word_sequences, maxlen=max_sequence_len, padding='pre'))

# %%
xs, labels = input_sequences[:, :-1], input_sequences[:,-1]

# %%
ys = tf.keras.utils.to_categorical(labels, num_classes=total_words)

# %%
model = Sequential()
model.add(Embedding(total_words, 64, input_length = max_sequence_len-1))
model.add(Bidirectional(LSTM(20)))
model.add(Dense(total_words, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(xs, ys, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 1462/1462 [==============================] - 14s 7ms/step - loss: 6.7426 - accuracy: 0.0331
# Epoch 2/100
# 1462/1462 [==============================] - 11s 7ms/step - loss: 6.3862 - accuracy: 0.0366
# Epoch 3/100
# 1462/1462 [==============================] - 11s 7ms/step - loss: 6.2286 - accuracy: 0.0437
# Epoch 4/100
# 1462/1462 [==============================] - 11s 7ms/step - loss: 6.0751 - accuracy: 0.0620
# Epoch 5/100
# 1462/1462 [==============================] - 10s 7ms/step - loss: 5.9537 - accuracy: 0.0769
# Epoch 6/100
# 1462/1462 [==============================] - 10s 7ms/step - loss: 5.8337 - accuracy: 0.0906
# Epoch 7/100
# 1462/1462 [==============================] - 11s 8ms/step - loss: 5.7133 - accuracy: 0.1011
# Epoch 8/100
# 1462/1462 [==============================] - 11s 7ms/step - loss: 5.5983 - accuracy: 0.1098
# Epoch 9/100
# 1462/1462 [==============================] - 11s 8ms/step - loss: 5.4902 - accuracy: 0.1172
# Epoch 10/100
# ...

# %%
import matplotlib.pyplot as plt

def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.xlabel('No of Epochs')
    plt.ylabel(string)
    plt.show

# %%
plot_graphs(history, 'accuracy');

# %%
seed_text = 'kiss my lips'
next_words = 100

for _ in range(next_words):
    token_list = tokenizer.texts_to_sequences([seed_text])[0]
    token_list = pad_sequences([token_list], maxlen = max_sequence_len-1, padding='pre')
    predicted = np.argmax(model.predict(token_list), axis=-1)
    
    output_word = ''
    for word, index in tokenizer.word_index.items():
        if index == predicted:
            output_word = word
            break
    seed_text += ' ' + output_word
print(seed_text)
# Out:
# ...
# 1/1 [==============================] - 0s 16ms/step
# kiss my lips and manhole cover my v is a space heater bottoms and pepsi just forgot about a tiny necklace locket across me that's me when they know you you am those thanks those clips lust it lust who's drivin' eatin' bought purplish dear away' dear alongside the door to mate you've about you and it seems like dear burgundy creek sincerity patch eatin' wait purplish what's lust who's lust who's lust who's drivin' eatin' throating sporadic argh and drives 'em motivated and powdered sporadic mathers eatin' rotation spinnin' eatin' bought backpack bought christopher joint dear away' who's lust lust kong lust
